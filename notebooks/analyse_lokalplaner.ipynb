# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
DATA_DIR = PROJECT_ROOT / "data"

gdf = gpd.read_file(DATA_DIR / "lokalplan_vedtaget_utm.geojson")

# %% [markdown]
# Antal planer pr. kommunune

# %%
gdf_detail = 
gdf["kommunekode"].value_counts()
# Out:
# kommunekode
# 751    2000
# 561    2000
# 860    1622
# 101    1493
# 760    1439
#        ...
# 163     117
# 741     117
# 825     113
# 563     111
# 183      99
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# Geometriplot

# %%
gdf.plot(figsize=(8, 8))
plt.show()

# %% [markdown]
# Areal af geometrier

# %%
gdf_utm = gdf.to_crs(25832)
gdf_utm["areal_m2"] = gdf_utm.area
gdf_utm[["plannavn", "areal_m2"]].head()
# Out:
#                   plannavn     areal_m2
# 0            Samuelskirken   942.748005
# 1            Jernbane Allé  4671.830331
# 2               Vibevej 25  2952.686179
# 3      Omøgade II tillæg 1  3794.234584
# 4  Bro ved Vester Voldgade  9555.210637

# %% [markdown]
# Københavns kommune

# %%
gdf_kbh = gdf[gdf["kommunekode"] == 101]
gdf_kbh.plot()
# Out:
# <Axes: >
